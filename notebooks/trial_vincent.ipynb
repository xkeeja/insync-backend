518268, 10.909239891972478, 20.508029859131934, 9.53670885482475, 9.541934599401072, 31.427697537536186, 31.275691848397816, 28.817395914057315, 55.889611021875766, 55.325960481458125, 31.307604627013433, 31.66771933926791, 24.539033571105, 22.050203953700724, 21.7104605607124, 35.15297532218937, 35.1903459012745, 13.288368181267264, 25.12875847854715, 25.07549555407867, 48.43602818316188, 48.48663118776824, 49.120068728124366, 26.063880489237604, 26.06610714477452, 27.710656640882966, 27.701546363414963, 25.97187761296132, 25.993574877987747, 26.06453174380772, 8.710237209596297, 26.381873754831606, 8.137500561081875, 8.165742746355377, 8.16433841382641, 26.09026876322364, 26.09277617680669, 28.155588897531718, 23.96518684435764, 23.98476974666058, 23.387190147902444, 23.448296277310508, 6.033950929799401, 26.513367103105544, 26.515952500896248, 4.622487253544188, 4.6133270402287465, 6.204610586489891, 7.000753730384706, 7.137765371624148, 4.8553289947341485, 4.573688668264849, 5.620490410598169, 11.280566155980065, 11.33210273661821, 12.699074304486919, 12.911093488886806, 8.513394102408014, 6.75572453363288, 6.72451860117148, 6.2554428909925175, 6.34409208852545, 5.819467683031739, 31.503887826189786, 31.50681150364914, 13.331937238037014, 13.124116752010893, 23.36427629430979, 36.43306925379389, 36.28050948831611, 33.65975373699717, 33.71150537170678, 35.60764571694614, 27.485311587054102, 27.523830655993272, 25.65637196780279, 14.399632722122757, 26.935949402835526, 18.034468222922484, 18.09085888810924, 17.261319132749545, 19.180766952509515, 31.689760214997772, 15.662334470113834, 15.737442313699948, 18.581434093776572, 18.019487453851337, 33.08395059928712, 53.76227436008036, 39.76247444351155, 58.05110883441486, 70.67301032159617]

# %%
import matplotlib.pyplot as plt 
import numpy as np

print(np.mean(score))
score2 = [np.mean(score[i-1] + score[i] + score[i-1])for i in range(249)]
y=np.arange(249 )/30
plt.figure(figsize=(20,8))
plt.plot(y, score2)
# Out:
# 23.379540829602327

# %%
import matplotlib.pyplot as plt 
import numpy as np

k=4
print(np.mean(score))
score2 = [np.mean(score[i-k : i+k+1]) for i in range(249)]
y=np.arange(249 )/30
plt.figure(figsize=(20,8))
plt.plot(y, score2)
# Out:
# 23.379540829602327
# /root/.pyenv/versions/lewagon/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /root/.pyenv/versions/lewagon/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
import matplotlib.pyplot as plt 
import numpy as np

k=1
print(np.mean(score))
score2 = [np.mean(score[i-k : i+k+1]) for i in range(249)]
y=np.arange(249 )/30
plt.figure(figsize=(20,8))
plt.plot(y, score2)
# Out:
# 23.379540829602327
# /root/.pyenv/versions/lewagon/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /root/.pyenv/versions/lewagon/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
import matplotlib.pyplot as plt 
import numpy as np

k=0
print(np.mean(score))
score2 = [np.mean(score[i-k : i+k+1]) for i in range(249)]
y=np.arange(249 )/30
plt.figure(figsize=(20,8))
plt.plot(y, score2)
# Out:
# 23.379540829602327
